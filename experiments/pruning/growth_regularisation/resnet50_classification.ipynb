# %% [markdown]
# <h1>Growth Regularisation</h1>
# This notebook demonstrates the implementation of this paper <a href=https://arxiv.org/abs/2012.09243> Neural Pruning Via Growth Regularisation</a>
# <h4>Steps to train a baseline model and then compress it given a channel budget are as follows:</h4>
# <ul>
#     <li>Load the YAML file. </li>
#     <li>Load dataset and create dataloaders. </li>
#     <li>Create <b>Growth Regularisation</b> object and pass the parameters in the form of a dictionary. </li>
#     <li>Pass the dataloaders into the <b>compress_model</b> method to obtain the compressed model. </li>
# </ul>
# Since this is a demo notebook the number of epochs have been set to 2.

# %%
import sys
import os
sys.path.append("../../")
sys.path.append("../../../")
os.environ['CUDA_VISIBLE_DEVICES']='2'

import torch
from torchvision import transforms

import yaml

from trailmet.datasets.classification import DatasetFactory
from trailmet.algorithms.prune.growth_regularisation import Growth_Regularisation

# %%
# !pwd
root = "/workspace/code/Nahush26/trail/trailmet/experiments/pruning/growth_regularisation"
# Out:
# /workspace/code/Nahush26/trail/trailmet/experiments/pruning/growth_regularisation

# %% [markdown]
# <h3> Loading the YAML file. </h3>

# %%
with open(os.path.join(root, "resnet50_cifar100.yaml"), 'r') as stream:
    data_loaded = yaml.safe_load(stream)
data_loaded
# Out:
# {'num_classes': 100,
#  'weight_decay': 0.0005,
#  'arch': 'resnet50',
#  'dataset': 'cifar100',
#  'epochs': 1,
#  'learning_rate': 0.002,
#  'prune_ratio': 0.5,
#  'reg_upper_limit': 0.0004,
#  'reg_granularity_prune': 0.0002,
#  'method': 'GReg-1'}

# %% [markdown]
# <h3>Loading CIFAR100Dataset</h3>

# %%
transform_train = transforms.Compose(
                [
                    transforms.ToTensor(),
                    transforms.Pad(4, padding_mode='reflect'),
                    transforms.RandomHorizontalFlip(p=0.5),
                    transforms.RandomCrop(32),
                    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
                ]
            )

transform_test = transforms.Compose(
                [
                    transforms.ToTensor(),
                    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
                ]
            )

transforms1 = {
    'train': transform_train, 
    'val': transform_test, 
    'test': transform_test}

target_transforms = {
    'train': None, 
    'val': None, 
    'test': None}

cifar_dataset = DatasetFactory.create_dataset(name = 'CIFAR100', 
                                        root = "./data",
                                        split_types = ['train', 'val', 'test'],
                                        val_fraction = 0.1,
                                        transform = transforms1,
                                        target_transform = target_transforms,
                                        random_seed=42
                                        )
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <h5>Creating the dataloaders</h5>

# %%
dataloaders = { 'train' : torch.utils.data.DataLoader(
        cifar_dataset['train'], batch_size=64, 
        sampler=cifar_dataset['train_sampler'],
        num_workers=0
    ),
               'val':  torch.utils.data.DataLoader(
        cifar_dataset['val'], batch_size=64, 
        sampler=cifar_dataset['val_sampler'],
        num_workers=0
    ),  
               'test':  torch.utils.data.DataLoader(
        cifar_dataset['test'], batch_size=64, 
        sampler=cifar_dataset['test_sampler'],
        num_workers=0
    )}

# %% [markdown]
# <h3> Creating the method's object proceed with compression. </h3>

# %%
slim = Growth_Regularisation()
# Out:
# cd /workspace/code/Nahush26/trail/trailmet/experiments/pruning/growth_regularisation
# CUDA_VISIBLE_DEVICES=2 python /opt/conda/lib/python3.8/site-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-22910f2f-f08c-477b-8851-4948dcc52014.json
#
# ExpNote [-utils-194418]: " " -- TrAIL

# %%
slim.compress_model(dataloaders)
# Out:
# EPOCH NUMBER  0
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:57<00:00,  5.99it/s, loss=4.47]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:04<00:00, 16.39it/s, acc=0.0242, loss=8.88]
# **Saving model**
# Register layer index and kernel shape:
# [ 0]                 conv1 -- kernel_shape: torch.Size([64, 3, 3, 3])
# [ 1]        layer1.0.conv1 -- kernel_shape: torch.Size([64, 64, 1, 1])
# [ 2]        layer1.0.conv2 -- kernel_shape: torch.Size([64, 64, 3, 3])
# [ 3]        layer1.0.conv3 -- kernel_shape: torch.Size([256, 64, 1, 1])
# [ 3] layer1.0.downsample.0 -- kernel_shape: torch.Size([256, 64, 1, 1])
# [ 4]        layer1.1.conv1 -- kernel_shape: torch.Size([64, 256, 1, 1])
# [ 5]        layer1.1.conv2 -- kernel_shape: torch.Size([64, 64, 3, 3])
# [ 6]        layer1.1.conv3 -- kernel_shape: torch.Size([256, 64, 1, 1])
# [ 7]        layer1.2.conv1 -- kernel_shape: torch.Size([64, 256, 1, 1])
# [ 8]        layer1.2.conv2 -- kernel_shape: torch.Size([64, 64, 3, 3])
# [ 9]        layer1.2.conv3 -- kernel_shape: torch.Size([256, 64, 1, 1])
# [10]        layer2.0.conv1 -- kernel_shape: torch.Size([128, 256, 1, 1])
# [11]        layer2.0.conv2 -- kernel_shape: torch.Size([128, 128, 3, 3])
# [12]        layer2.0.conv3 -- kernel_shape: torch.Size([512, 128, 1, 1])
# [12] layer2.0.downsample.0 -- kernel_shape: torch.Size([512, 256, 1, 1])
# [13]        layer2.1.conv1 -- kernel_shape: torch.Size([128, 512, 1, 1])
# [14]        layer2.1.conv2 -- kernel_shape: torch.Size([128, 128, 3, 3])
# [15]        layer2.1.conv3 -- kernel_shape: torch.Size([512, 128, 1, 1])
# [16]        layer2.2.conv1 -- kernel_shape: torch.Size([128, 512, 1, 1])
# [17]        layer2.2.conv2 -- kernel_shape: torch.Size([128, 128, 3, 3])
# [18]        layer2.2.conv3 -- kernel_shape: torch.Size([512, 128, 1, 1])
# [19]        layer2.3.conv1 -- kernel_shape: torch.Size([128, 512, 1, 1])
# [20]        layer2.3.conv2 -- kernel_shape: torch.Size([128, 128, 3, 3])
# [21]        layer2.3.conv3 -- kernel_shape: torch.Size([512, 128, 1, 1])
# [22]        layer3.0.conv1 -- kernel_shape: torch.Size([256, 512, 1, 1])
# [23]        layer3.0.conv2 -- kernel_shape: torch.Size([256, 256, 3, 3])
# [24]        layer3.0.conv3 -- kernel_shape: torch.Size([1024, 256, 1, 1])
# [24] layer3.0.downsample.0 -- kernel_shape: torch.Size([1024, 512, 1, 1])
# [25]        layer3.1.conv1 -- kernel_shape: torch.Size([256, 1024, 1, 1])
# [26]        layer3.1.conv2 -- kernel_shape: torch.Size([256, 256, 3, 3])
# [27]        layer3.1.conv3 -- kernel_shape: torch.Size([1024, 256, 1, 1])
# [28]        layer3.2.conv1 -- kernel_shape: torch.Size([256, 1024, 1, 1])
# [29]        layer3.2.conv2 -- kernel_shape: torch.Size([256, 256, 3, 3])
# [30]        layer3.2.conv3 -- kernel_shape: torch.Size([1024, 256, 1, 1])
# [31]        layer3.3.conv1 -- kernel_shape: torch.Size([256, 1024, 1, 1])
# [32]        layer3.3.conv2 -- kernel_shape: torch.Size([256, 256, 3, 3])
# [33]        layer3.3.conv3 -- kernel_shape: torch.Size([1024, 256, 1, 1])
# [34]        layer3.4.conv1 -- kernel_shape: torch.Size([256, 1024, 1, 1])
# [35]        layer3.4.conv2 -- kernel_shape: torch.Size([256, 256, 3, 3])
# [36]        layer3.4.conv3 -- kernel_shape: torch.Size([1024, 256, 1, 1])
# [37]        layer3.5.conv1 -- kernel_shape: torch.Size([256, 1024, 1, 1])
# [38]        layer3.5.conv2 -- kernel_shape: torch.Size([256, 256, 3, 3])
# [39]        layer3.5.conv3 -- kernel_shape: torch.Size([1024, 256, 1, 1])
# [40]        layer4.0.conv1 -- kernel_shape: torch.Size([512, 1024, 1, 1])
# [41]        layer4.0.conv2 -- kernel_shape: torch.Size([512, 512, 3, 3])
# [42]        layer4.0.conv3 -- kernel_shape: torch.Size([2048, 512, 1, 1])
# [42] layer4.0.downsample.0 -- kernel_shape: torch.Size([2048, 1024, 1, 1])
# [43]        layer4.1.conv1 -- kernel_shape: torch.Size([512, 2048, 1, 1])
# [44]        layer4.1.conv2 -- kernel_shape: torch.Size([512, 512, 3, 3])
# [45]        layer4.1.conv3 -- kernel_shape: torch.Size([2048, 512, 1, 1])
# [46]        layer4.2.conv1 -- kernel_shape: torch.Size([512, 2048, 1, 1])
# [47]        layer4.2.conv2 -- kernel_shape: torch.Size([512, 512, 3, 3])
# [48]        layer4.2.conv3 -- kernel_shape: torch.Size([2048, 512, 1, 1])
# [49]                    fc -- kernel_shape: torch.Size([100, 2048])
# update_reg 0 1
# Experiments/TrAIL_SERVER-20230323-194418/weights 0 0
# 0
# {'conv1': tensor(0.0002, device='cuda:0'), 'layer1.0.conv1': tensor(0.0002, device='cuda:0'), 'layer1.0.conv3': tensor(0.0002, device='cuda:0'), 'layer1.1.conv1': tensor(0.0002, device='cuda:0'), 'layer1.1.conv3': tensor(0.0002, device='cuda:0'), 'layer1.2.conv1': tensor(0.0002, device='cuda:0'), 'layer1.2.conv3': tensor(0.0002, device='cuda:0'), 'layer2.0.conv1': tensor(0.0002, device='cuda:0'), 'layer2.0.conv3': tensor(0.0002, device='cuda:0'), 'layer2.1.conv1': tensor(0.0002, device='cuda:0'), 'layer2.1.conv3': tensor(0.0002, device='cuda:0'), 'layer2.2.conv1': tensor(0.0002, device='cuda:0'), 'layer2.2.conv3': tensor(0.0002, device='cuda:0'), 'layer2.3.conv1': tensor(0.0002, device='cuda:0'), 'layer2.3.conv3': tensor(0.0002, device='cuda:0'), 'layer3.0.conv1': tensor(0.0002, device='cuda:0'), 'layer3.0.conv3': tensor(0.0002, device='cuda:0'), 'layer3.1.conv1': tensor(0.0002, device='cuda:0'), 'layer3.1.conv3': tensor(0.0002, device='cuda:0'), 'layer3.2.conv1': tensor(0.0002, device='cuda:0'), 'layer3.2.conv3': tensor(0.0002, device='cuda:0'), 'layer3.3.conv1': tensor(0.0002, device='cuda:0'), 'layer3.3.conv3': tensor(0.0002, device='cuda:0'), 'layer3.4.conv1': tensor(0.0002, device='cuda:0'), 'layer3.4.conv3': tensor(0.0002, device='cuda:0'), 'layer3.5.conv1': tensor(0.0002, device='cuda:0'), 'layer3.5.conv3': tensor(0.0002, device='cuda:0'), 'layer4.0.conv1': tensor(0.0002, device='cuda:0'), 'layer4.0.conv3': tensor(0.0002, device='cuda:0'), 'layer4.1.conv1': tensor(0.0002, device='cuda:0'), 'layer4.1.conv3': tensor(0.0002, device='cuda:0'), 'layer4.2.conv1': tensor(0.0002, device='cuda:0'), 'layer4.2.conv3': tensor(0.0002, device='cuda:0'), 'fc': tensor(0.0002, device='cuda:0')}
# stabilize_reg 1 1
# ============shortcuts [0]===========
# model.layer1.0.bn3: 120
# model.layer1.0.downsample.1: 136
# model.layer1.1.bn3: 134
# model.layer1.2.bn3: 130
# merged indexes length: 246
# ============shortcuts [1]===========
# model.layer2.0.bn3: 273
# model.layer2.0.downsample.1: 285
# model.layer2.1.bn3: 296
# model.layer2.2.bn3: 319
# model.layer2.3.bn3: 341
# merged indexes length: 509
# ============shortcuts [2]===========
# model.layer3.0.bn3: 571
# model.layer3.0.downsample.1: 477
# model.layer3.1.bn3: 734
# model.layer3.2.bn3: 769
# model.layer3.3.bn3: 841
# model.layer3.4.bn3: 887
# model.layer3.5.bn3: 889
# merged indexes length: 1024
# ============shortcuts [3]===========
# model.layer4.0.bn3: 623
# model.layer4.0.downsample.1: 420
# model.layer4.1.bn3: 177
# model.layer4.2.bn3: 715
# merged indexes length: 1394
#
# BatchNorm2d prune info
# |    | name                        | channels   | prune percent   |
# |---:|:----------------------------|:-----------|:----------------|
# |  0 | model.bn1                   | 26/64      | 59.38%          |
# |  1 | model.layer1.0.bn1          | 30/64      | 53.12%          |
# |  2 | model.layer1.0.bn2          | 30/64      | 53.12%          |
# |  3 | model.layer1.0.bn3          | 246/256    | 3.91%           |
# |  4 | model.layer1.0.downsample.1 | 246/256    | 3.91%           |
# |  5 | model.layer1.1.bn1          | 31/64      | 51.56%          |
# |  6 | model.layer1.1.bn2          | 27/64      | 57.81%          |
# |  7 | model.layer1.1.bn3          | 246/256    | 3.91%           |
# |  8 | model.layer1.2.bn1          | 30/64      | 53.12%          |
# |  9 | model.layer1.2.bn2          | 36/64      | 43.75%          |
# | 10 | model.layer1.2.bn3          | 246/256    | 3.91%           |
# | 11 | model.layer2.0.bn1          | 66/128     | 48.44%          |
# | 12 | model.layer2.0.bn2          | 61/128     | 52.34%          |
# | 13 | model.layer2.0.bn3          | 509/512    | 0.59%           |
# | 14 | model.layer2.0.downsample.1 | 509/512    | 0.59%           |
# | 15 | model.layer2.1.bn1          | 64/128     | 50.00%          |
# | 16 | model.layer2.1.bn2          | 59/128     | 53.91%          |
# | 17 | model.layer2.1.bn3          | 509/512    | 0.59%           |
# | 18 | model.layer2.2.bn1          | 64/128     | 50.00%          |
# | 19 | model.layer2.2.bn2          | 59/128     | 53.91%          |
# | 20 | model.layer2.2.bn3          | 509/512    | 0.59%           |
# | 21 | model.layer2.3.bn1          | 63/128     | 50.78%          |
# | 22 | model.layer2.3.bn2          | 60/128     | 53.12%          |
# | 23 | model.layer2.3.bn3          | 509/512    | 0.59%           |
# | 24 | model.layer3.0.bn1          | 138/256    | 46.09%          |
# | 25 | model.layer3.0.bn2          | 131/256    | 48.83%          |
# | 26 | model.layer3.0.bn3          | 1024/1024  | 0.00%           |
# | 27 | model.layer3.0.downsample.1 | 1024/1024  | 0.00%           |
# | 28 | model.layer3.1.bn1          | 140/256    | 45.31%          |
# | 29 | model.layer3.1.bn2          | 136/256    | 46.88%          |
# | 30 | model.layer3.1.bn3          | 1024/1024  | 0.00%           |
# | 31 | model.layer3.2.bn1          | 134/256    | 47.66%          |
# | 32 | model.layer3.2.bn2          | 137/256    | 46.48%          |
# | 33 | model.layer3.2.bn3          | 1024/1024  | 0.00%           |
# | 34 | model.layer3.3.bn1          | 144/256    | 43.75%          |
# | 35 | model.layer3.3.bn2          | 139/256    | 45.70%          |
# | 36 | model.layer3.3.bn3          | 1024/1024  | 0.00%           |
# | 37 | model.layer3.4.bn1          | 156/256    | 39.06%          |
# | 38 | model.layer3.4.bn2          | 148/256    | 42.19%          |
# | 39 | model.layer3.4.bn3          | 1024/1024  | 0.00%           |
# | 40 | model.layer3.5.bn1          | 159/256    | 37.89%          |
# | 41 | model.layer3.5.bn2          | 146/256    | 42.97%          |
# | 42 | model.layer3.5.bn3          | 1024/1024  | 0.00%           |
# | 43 | model.layer4.0.bn1          | 282/512    | 44.92%          |
# | 44 | model.layer4.0.bn2          | 284/512    | 44.53%          |
# | 45 | model.layer4.0.bn3          | 1394/2048  | 31.93%          |
# | 46 | model.layer4.0.downsample.1 | 1394/2048  | 31.93%          |
# | 47 | model.layer4.1.bn1          | 295/512    | 42.38%          |
# | 48 | model.layer4.1.bn2          | 286/512    | 44.14%          |
# | 49 | model.layer4.1.bn3          | 1394/2048  | 31.93%          |
# | 50 | model.layer4.2.bn1          | 297/512    | 41.99%          |
# | 51 | model.layer4.2.bn2          | 284/512    | 44.53%          |
# | 52 | model.layer4.2.bn3          | 1394/2048  | 31.93%          |
#
#
# Conv2d prune info
# |    | name                        | weight shape    | pruned weight shape   | prune percent   |
# |---:|:----------------------------|:----------------|:----------------------|:----------------|
# |  0 | model.conv1                 | [3,64] g=1      | [3,26] g=1            | 59.38%          |
# |  1 | model.layer1.0.conv1        | [64,64] g=1     | [26,30] g=1           | 80.96%          |
# |  2 | model.layer1.0.conv2        | [64,64] g=1     | [30,30] g=1           | 78.03%          |
# |  3 | model.layer1.0.conv3        | [64,256] g=1    | [30,246] g=1          | 54.96%          |
# |  4 | model.layer1.0.downsample.0 | [64,256] g=1    | [26,246] g=1          | 60.96%          |
# |  5 | model.layer1.1.conv1        | [256,64] g=1    | [246,31] g=1          | 53.45%          |
# |  6 | model.layer1.1.conv2        | [64,64] g=1     | [31,27] g=1           | 79.57%          |
# |  7 | model.layer1.1.conv3        | [64,256] g=1    | [27,246] g=1          | 59.46%          |
# |  8 | model.layer1.2.conv1        | [256,64] g=1    | [246,30] g=1          | 54.96%          |
# |  9 | model.layer1.2.conv2        | [64,64] g=1     | [30,36] g=1           | 73.63%          |
# | 10 | model.layer1.2.conv3        | [64,256] g=1    | [36,246] g=1          | 45.95%          |
# | 11 | model.layer2.0.conv1        | [256,128] g=1   | [246,66] g=1          | 50.45%          |
# | 12 | model.layer2.0.conv2        | [128,128] g=1   | [66,61] g=1           | 75.43%          |
# | 13 | model.layer2.0.conv3        | [128,512] g=1   | [61,509] g=1          | 52.62%          |
# | 14 | model.layer2.0.downsample.0 | [256,512] g=1   | [246,509] g=1         | 4.47%           |
# | 15 | model.layer2.1.conv1        | [512,128] g=1   | [509,64] g=1          | 50.29%          |
# | 16 | model.layer2.1.conv2        | [128,128] g=1   | [64,59] g=1           | 76.95%          |
# | 17 | model.layer2.1.conv3        | [128,512] g=1   | [59,509] g=1          | 54.18%          |
# | 18 | model.layer2.2.conv1        | [512,128] g=1   | [509,64] g=1          | 50.29%          |
# | 19 | model.layer2.2.conv2        | [128,128] g=1   | [64,59] g=1           | 76.95%          |
# | 20 | model.layer2.2.conv3        | [128,512] g=1   | [59,509] g=1          | 54.18%          |
# | 21 | model.layer2.3.conv1        | [512,128] g=1   | [509,63] g=1          | 51.07%          |
# | 22 | model.layer2.3.conv2        | [128,128] g=1   | [63,60] g=1           | 76.93%          |
# | 23 | model.layer2.3.conv3        | [128,512] g=1   | [60,509] g=1          | 53.40%          |
# | 24 | model.layer3.0.conv1        | [512,256] g=1   | [509,138] g=1         | 46.41%          |
# | 25 | model.layer3.0.conv2        | [256,256] g=1   | [138,131] g=1         | 72.42%          |
# | 26 | model.layer3.0.conv3        | [256,1024] g=1  | [131,1024] g=1        | 48.83%          |
# | 27 | model.layer3.0.downsample.0 | [512,1024] g=1  | [509,1024] g=1        | 0.59%           |
# | 28 | model.layer3.1.conv1        | [1024,256] g=1  | [1024,140] g=1        | 45.31%          |
# | 29 | model.layer3.1.conv2        | [256,256] g=1   | [140,136] g=1         | 70.95%          |
# | 30 | model.layer3.1.conv3        | [256,1024] g=1  | [136,1024] g=1        | 46.88%          |
# | 31 | model.layer3.2.conv1        | [1024,256] g=1  | [1024,134] g=1        | 47.66%          |
# | 32 | model.layer3.2.conv2        | [256,256] g=1   | [134,137] g=1         | 71.99%          |
# | 33 | model.layer3.2.conv3        | [256,1024] g=1  | [137,1024] g=1        | 46.48%          |
# | 34 | model.layer3.3.conv1        | [1024,256] g=1  | [1024,144] g=1        | 43.75%          |
# | 35 | model.layer3.3.conv2        | [256,256] g=1   | [144,139] g=1         | 69.46%          |
# | 36 | model.layer3.3.conv3        | [256,1024] g=1  | [139,1024] g=1        | 45.70%          |
# | 37 | model.layer3.4.conv1        | [1024,256] g=1  | [1024,156] g=1        | 39.06%          |
# | 38 | model.layer3.4.conv2        | [256,256] g=1   | [156,148] g=1         | 64.77%          |
# | 39 | model.layer3.4.conv3        | [256,1024] g=1  | [148,1024] g=1        | 42.19%          |
# | 40 | model.layer3.5.conv1        | [1024,256] g=1  | [1024,159] g=1        | 37.89%          |
# | 41 | model.layer3.5.conv2        | [256,256] g=1   | [159,146] g=1         | 64.58%          |
# | 42 | model.layer3.5.conv3        | [256,1024] g=1  | [146,1024] g=1        | 42.97%          |
# | 43 | model.layer4.0.conv1        | [1024,512] g=1  | [1024,282] g=1        | 44.92%          |
# | 44 | model.layer4.0.conv2        | [512,512] g=1   | [282,284] g=1         | 69.45%          |
# | 45 | model.layer4.0.conv3        | [512,2048] g=1  | [284,1394] g=1        | 62.24%          |
# | 46 | model.layer4.0.downsample.0 | [1024,2048] g=1 | [1024,1394] g=1       | 31.93%          |
# | 47 | model.layer4.1.conv1        | [2048,512] g=1  | [1394,295] g=1        | 60.78%          |
# | 48 | model.layer4.1.conv2        | [512,512] g=1   | [295,286] g=1         | 67.82%          |
# | 49 | model.layer4.1.conv3        | [512,2048] g=1  | [286,1394] g=1        | 61.98%          |
# | 50 | model.layer4.2.conv1        | [2048,512] g=1  | [1394,297] g=1        | 60.52%          |
# | 51 | model.layer4.2.conv2        | [512,512] g=1   | [297,284] g=1         | 67.82%          |
# | 52 | model.layer4.2.conv3        | [512,2048] g=1  | [284,1394] g=1        | 62.24%          |
#
#
# Conv2d after cat prune info
#
#
#
# Linear prune info
# |    | name     | in_features   |   prune percent |
# |---:|:---------|:--------------|----------------:|
# |  0 | model.fc | 1394/2048     |           31.93 |
#
# Summary of pruned_model
# |     | name                        | module                                                                            |
# |----:|:----------------------------|:----------------------------------------------------------------------------------|
# |   0 | model.conv1                 | Conv2d(3, 26, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)      |
# |   1 | model.bn1                   | BatchNorm2d(26, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |   2 | model.layer1.0.conv1        | Conv2d(26, 30, kernel_size=(1, 1), stride=(1, 1), bias=False)                     |
# |   3 | model.layer1.0.bn1          | BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |   4 | model.layer1.0.conv2        | Conv2d(30, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)     |
# |   5 | model.layer1.0.bn2          | BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |   6 | model.layer1.0.conv3        | Conv2d(30, 246, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |   7 | model.layer1.0.bn3          | BatchNorm2d(246, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |   8 | model.layer1.0.downsample.0 | Conv2d(26, 246, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |   9 | model.layer1.0.downsample.1 | BatchNorm2d(246, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  10 | model.layer1.1.conv1        | Conv2d(246, 31, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |  11 | model.layer1.1.bn1          | BatchNorm2d(31, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |  12 | model.layer1.1.conv2        | Conv2d(31, 27, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)     |
# |  13 | model.layer1.1.bn2          | BatchNorm2d(27, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |  14 | model.layer1.1.conv3        | Conv2d(27, 246, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |  15 | model.layer1.1.bn3          | BatchNorm2d(246, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  16 | model.layer1.2.conv1        | Conv2d(246, 30, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |  17 | model.layer1.2.bn1          | BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |  18 | model.layer1.2.conv2        | Conv2d(30, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)     |
# |  19 | model.layer1.2.bn2          | BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |  20 | model.layer1.2.conv3        | Conv2d(36, 246, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |  21 | model.layer1.2.bn3          | BatchNorm2d(246, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  22 | model.layer2.0.conv1        | Conv2d(246, 66, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |  23 | model.layer2.0.bn1          | BatchNorm2d(66, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |  24 | model.layer2.0.conv2        | Conv2d(66, 61, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)     |
# |  25 | model.layer2.0.bn2          | BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |  26 | model.layer2.0.conv3        | Conv2d(61, 509, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |  27 | model.layer2.0.bn3          | BatchNorm2d(509, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  28 | model.layer2.0.downsample.0 | Conv2d(246, 509, kernel_size=(1, 1), stride=(2, 2), bias=False)                   |
# |  29 | model.layer2.0.downsample.1 | BatchNorm2d(509, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  30 | model.layer2.1.conv1        | Conv2d(509, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |  31 | model.layer2.1.bn1          | BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |  32 | model.layer2.1.conv2        | Conv2d(64, 59, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)     |
# |  33 | model.layer2.1.bn2          | BatchNorm2d(59, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |  34 | model.layer2.1.conv3        | Conv2d(59, 509, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |  35 | model.layer2.1.bn3          | BatchNorm2d(509, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  36 | model.layer2.2.conv1        | Conv2d(509, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |  37 | model.layer2.2.bn1          | BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |  38 | model.layer2.2.conv2        | Conv2d(64, 59, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)     |
# |  39 | model.layer2.2.bn2          | BatchNorm2d(59, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |  40 | model.layer2.2.conv3        | Conv2d(59, 509, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |  41 | model.layer2.2.bn3          | BatchNorm2d(509, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  42 | model.layer2.3.conv1        | Conv2d(509, 63, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |  43 | model.layer2.3.bn1          | BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |  44 | model.layer2.3.conv2        | Conv2d(63, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)     |
# |  45 | model.layer2.3.bn2          | BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)   |
# |  46 | model.layer2.3.conv3        | Conv2d(60, 509, kernel_size=(1, 1), stride=(1, 1), bias=False)                    |
# |  47 | model.layer2.3.bn3          | BatchNorm2d(509, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  48 | model.layer3.0.conv1        | Conv2d(509, 138, kernel_size=(1, 1), stride=(1, 1), bias=False)                   |
# |  49 | model.layer3.0.bn1          | BatchNorm2d(138, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  50 | model.layer3.0.conv2        | Conv2d(138, 131, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)   |
# |  51 | model.layer3.0.bn2          | BatchNorm2d(131, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  52 | model.layer3.0.conv3        | Conv2d(131, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  53 | model.layer3.0.bn3          | BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) |
# |  54 | model.layer3.0.downsample.0 | Conv2d(509, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)                  |
# |  55 | model.layer3.0.downsample.1 | BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) |
# |  56 | model.layer3.1.conv1        | Conv2d(1024, 140, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  57 | model.layer3.1.bn1          | BatchNorm2d(140, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  58 | model.layer3.1.conv2        | Conv2d(140, 136, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)   |
# |  59 | model.layer3.1.bn2          | BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  60 | model.layer3.1.conv3        | Conv2d(136, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  61 | model.layer3.1.bn3          | BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) |
# |  62 | model.layer3.2.conv1        | Conv2d(1024, 134, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  63 | model.layer3.2.bn1          | BatchNorm2d(134, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  64 | model.layer3.2.conv2        | Conv2d(134, 137, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)   |
# |  65 | model.layer3.2.bn2          | BatchNorm2d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  66 | model.layer3.2.conv3        | Conv2d(137, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  67 | model.layer3.2.bn3          | BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) |
# |  68 | model.layer3.3.conv1        | Conv2d(1024, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  69 | model.layer3.3.bn1          | BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  70 | model.layer3.3.conv2        | Conv2d(144, 139, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)   |
# |  71 | model.layer3.3.bn2          | BatchNorm2d(139, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  72 | model.layer3.3.conv3        | Conv2d(139, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  73 | model.layer3.3.bn3          | BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) |
# |  74 | model.layer3.4.conv1        | Conv2d(1024, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  75 | model.layer3.4.bn1          | BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  76 | model.layer3.4.conv2        | Conv2d(156, 148, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)   |
# |  77 | model.layer3.4.bn2          | BatchNorm2d(148, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  78 | model.layer3.4.conv3        | Conv2d(148, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  79 | model.layer3.4.bn3          | BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) |
# |  80 | model.layer3.5.conv1        | Conv2d(1024, 159, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  81 | model.layer3.5.bn1          | BatchNorm2d(159, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  82 | model.layer3.5.conv2        | Conv2d(159, 146, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)   |
# |  83 | model.layer3.5.bn2          | BatchNorm2d(146, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  84 | model.layer3.5.conv3        | Conv2d(146, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  85 | model.layer3.5.bn3          | BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) |
# |  86 | model.layer4.0.conv1        | Conv2d(1024, 282, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  87 | model.layer4.0.bn1          | BatchNorm2d(282, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  88 | model.layer4.0.conv2        | Conv2d(282, 284, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)   |
# |  89 | model.layer4.0.bn2          | BatchNorm2d(284, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  90 | model.layer4.0.conv3        | Conv2d(284, 1394, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  91 | model.layer4.0.bn3          | BatchNorm2d(1394, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) |
# |  92 | model.layer4.0.downsample.0 | Conv2d(1024, 1394, kernel_size=(1, 1), stride=(2, 2), bias=False)                 |
# |  93 | model.layer4.0.downsample.1 | BatchNorm2d(1394, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) |
# |  94 | model.layer4.1.conv1        | Conv2d(1394, 295, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  95 | model.layer4.1.bn1          | BatchNorm2d(295, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  96 | model.layer4.1.conv2        | Conv2d(295, 286, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)   |
# |  97 | model.layer4.1.bn2          | BatchNorm2d(286, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# |  98 | model.layer4.1.conv3        | Conv2d(286, 1394, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# |  99 | model.layer4.1.bn3          | BatchNorm2d(1394, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) |
# | 100 | model.layer4.2.conv1        | Conv2d(1394, 297, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# | 101 | model.layer4.2.bn1          | BatchNorm2d(297, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# | 102 | model.layer4.2.conv2        | Conv2d(297, 284, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)   |
# | 103 | model.layer4.2.bn2          | BatchNorm2d(284, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)  |
# | 104 | model.layer4.2.conv3        | Conv2d(284, 1394, kernel_size=(1, 1), stride=(1, 1), bias=False)                  |
# | 105 | model.layer4.2.bn3          | BatchNorm2d(1394, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True) |
# | 106 | model.fc                    | Linear(in_features=1394, out_features=100, bias=True)                             |
# **Saving model with key**
# LitModel(
#   (model): ResNet(
#     (conv1): Conv2d(3, 26, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(26, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): Identity()
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(26, 30, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(30, 30, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(30, 246, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(246, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(26, 246, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(246, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(246, 31, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(31, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(31, 27, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(27, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(27, 246, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(246, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(246, 30, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(30, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(36, 246, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(246, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(246, 66, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(66, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(66, 61, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(61, 509, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(509, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(246, 509, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(509, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(509, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 59, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(59, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(59, 509, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(509, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(509, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 59, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(59, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(59, 509, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(509, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(509, 63, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(63, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(63, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(60, 509, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(509, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(509, 138, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(138, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(138, 131, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(131, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(131, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(509, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 140, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(140, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(140, 136, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(136, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 134, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(134, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(134, 137, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(137, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(137, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(144, 139, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(139, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(139, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(156, 148, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(148, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(148, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 159, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(159, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(159, 146, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(146, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(146, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 282, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(282, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(282, 284, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(284, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(284, 1394, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1394, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 1394, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1394, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1394, 295, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(295, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(295, 286, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(286, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(286, 1394, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1394, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1394, 297, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(297, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(297, 284, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(284, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(284, 1394, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1394, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=1394, out_features=100, bias=True)
#   )
# )
# EPOCH NUMBER  0
#  81%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                              | 571/704 [01:09<00:16,  8.12it/s, loss=3.92]
